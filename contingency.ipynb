# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv('PG_campaigning.csv')
df_1
# Out:
#               Timestamp Who did you vote for as President?  \
# 0    4/14/2024 21:51:58                   Nihar Karthikeya
# 1    4/14/2024 22:05:57                    Rishi Cheekatla
# 2    4/14/2024 22:06:04                   Nihar Karthikeya
# 3    4/14/2024 22:06:04                   Nihar Karthikeya
# 4    4/14/2024 22:06:06                    Rishi Cheekatla
# ..                  ...                                ...
# 251  4/14/2024 22:05:57                   Nihar Karthikeya
# 252  4/14/2024 22:05:57                    Rishi Cheekatla
# 253  4/14/2024 22:05:57                   Nihar Karthikeya
# 254  4/14/2024 22:05:57                    Rishi Cheekatla
# 255  4/14/2024 22:05:57                   Nihar Karthikeya
#
#     If you chose NOTA/ didn't vote/ voted randomly, then reason for it:  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ...

# %%
df_1['Why did you vote for him?.1'].unique()
# Out:
# array(['Regional or some other kind of connection',
#        'Friends insisted to choose him', 'You found the agenda appealing',
#        'You are close friends (or) are from same branch',
#        'Just felt that he was better than the other',
#        "Voted Randomly/NOTA/ Didn't Vote"], dtype=object)

# %%
filtered_df = df_1[df_1['Your Program'].isin(['UG', 'PG'])]
filtered_df
# Out:
#               Timestamp Who did you vote for as President?  \
# 0    4/14/2024 21:51:58                   Nihar Karthikeya
# 1    4/14/2024 22:05:57                    Rishi Cheekatla
# 2    4/14/2024 22:06:04                   Nihar Karthikeya
# 3    4/14/2024 22:06:04                   Nihar Karthikeya
# 4    4/14/2024 22:06:06                    Rishi Cheekatla
# ..                  ...                                ...
# 251  4/14/2024 22:05:57                   Nihar Karthikeya
# 252  4/14/2024 22:05:57                    Rishi Cheekatla
# 253  4/14/2024 22:05:57                   Nihar Karthikeya
# 254  4/14/2024 22:05:57                    Rishi Cheekatla
# 255  4/14/2024 22:05:57                   Nihar Karthikeya
#
#     If you chose NOTA/ didn't vote/ voted randomly, then reason for it:  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ...

# %%
contingency_table = pd.crosstab(filtered_df['Your Program'], filtered_df['Why did you vote for him?.1'], margins=True, margins_name='Total')
(contingency_table)
# Out:
# Why did you vote for him?.1  Friends insisted to choose him  \
# Your Program
# PG                                                       13
# UG                                                       21
# Total                                                    34
#
# Why did you vote for him?.1  Just felt that he was better than the other  \
# Your Program
# PG                                                                    19
# UG                                                                    36
# Total                                                                 55
#
# Why did you vote for him?.1  Regional or some other kind of connection  \
# Your Program
# PG                                                                  12
# UG                                                                  15
# Total                                                               27
#
# Why did you vote for him?.1  Voted Randomly/NOTA/ Didn't Vote  \
# Your Program
# ...

# %%
import matplotlib.pyplot as plt

# Drop the 'Total' row to avoid duplicate bars
# contingency_table = contingency_table

# Plot the segmented bar graph
contingency_table.T.plot(kind='bar', stacked=True, figsize=(10, 6))

# Add labels and title
plt.xlabel('Program')
plt.ylabel('Count')
plt.title('Voting Reasons by Program')
plt.style('ggplot')

# Show the plot
plt.legend(title='Voting Reason')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 13
#      11 plt.ylabel('Count')
#      12 plt.title('Voting Reasons by Program')
# ---> 13 plt.style('ggplot')
#      15 # Show the plot
#      16 plt.legend(title='Voting Reason')
#
# TypeError: 'module' object is not callable

# %%
import matplotlib.pyplot as plt

# Drop the 'Total' row to avoid duplicate bars
# contingency_table = contingency_table

# Plot the segmented bar graph
contingency_table.T.plot(kind='bar', stacked=True, figsize=(10, 6))

# Add labels and title
plt.xlabel('Program')
plt.ylabel('Count')
plt.title('Voting Reasons by Program')

# Show the plot
plt.legend(title='Voting Reason')
plt.grid(True)
plt.show()
